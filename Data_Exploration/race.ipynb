# %% [markdown]
# # Male Vs Female Salary across different Race's
# #### There are 10 different Race's in the dataset: White, Hispanic, Asain, Korean, Chinese, Australian, Welsh, African American, Mixed, Black
# #### Data contains: Mean, median, standard deviation, max, min and range

# %%
import pandas as pd
import math
from tabulate import tabulate
salary_df = pd.read_csv("Salary.csv") 
male_df = salary_df[salary_df.Gender == "Male"]
female_df = salary_df[salary_df.Gender == "Female"]

# %%
#* Check of count for each 
White_count = salary_df[salary_df.Race == "White"].Salary.count()
Hispanic_count = salary_df[salary_df.Race == "Hispanic"].Salary.count()
Asian_count = salary_df[salary_df.Race == "Asian"].Salary.count()
Korean_count = salary_df[salary_df.Race == "Korean"].Salary.count()
Chinese_count = salary_df[salary_df.Race == "Chinese"].Salary.count()
Australian_count = salary_df[salary_df.Race == "Australian"].Salary.count()
welsh_count = salary_df[salary_df.Race == "Welsh"].Salary.count()
African_American_count = salary_df[salary_df.Race == "African American"].Salary.count()
Mixed_count = salary_df[salary_df.Race == "Mixed"].Salary.count()
Black_count = salary_df[salary_df.Race == "Black"].Salary.count()

print(White_count, Hispanic_count, Asian_count, Korean_count, Chinese_count, Australian_count, welsh_count, African_American_count, Mixed_count, Black_count)
# Relatively even for all except white count is roughly 5 times larger
# Out:
# 1957 322 1599 457 443 452 333 352 334 435

# %%
#! Mean
male_white_mean = round(male_df[male_df.Race == "White"].Salary.mean(), 2)
male_Hispanic_mean = round(male_df[male_df.Race == "Hispanic"].Salary.mean(), 2)
male_Asian_mean = round(male_df[male_df.Race == "Asian"].Salary.mean(), 2)
male_Korean_mean = round(male_df[male_df.Race == "Korean"].Salary.mean(), 2)
male_Chinese_mean = round(male_df[male_df.Race == "Chinese"].Salary.mean(), 2)
male_Australian_mean = round(male_df[male_df.Race == "Australian"].Salary.mean(), 2)
male_Welsh_mean = round(male_df[male_df.Race == "Welsh"].Salary.mean(), 2)
male_African_American_mean = round(male_df[male_df.Race == "African American"].Salary.mean(), 2)
male_Mixed_mean = round(male_df[male_df.Race == "Mixed"].Salary.mean(), 2)
male_Black_mean = round(male_df[male_df.Race == "Black"].Salary.mean(), 2)

female_white_mean = round(female_df[female_df.Race == "White"].Salary.mean(), 2)
female_Hispanic_mean = round(female_df[female_df.Race == "Hispanic"].Salary.mean(), 2)
female_Asian_mean = round(female_df[female_df.Race == "Asian"].Salary.mean(), 2)
female_Korean_mean = round(female_df[female_df.Race == "Korean"].Salary.mean(), 2)
female_Chinese_mean = round(female_df[female_df.Race == "Chinese"].Salary.mean(), 2)
female_Australian_mean = round(female_df[female_df.Race == "Australian"].Salary.mean(), 2)
female_Welsh_mean = round(female_df[female_df.Race == "Welsh"].Salary.mean(), 2)
female_African_American_mean = round(female_df[female_df.Race == "African American"].Salary.mean(), 2)
female_Mixed_mean = round(female_df[female_df.Race == "Mixed"].Salary.mean(), 2)
female_Black_mean = round(female_df[female_df.Race == "Black"].Salary.mean(), 2)

#! Median
male_white_median = round(male_df[male_df.Race == "White"].Salary.median(), 2)
male_Hispanic_median = round(male_df[male_df.Race == "Hispanic"].Salary.median(), 2)
male_Asian_median = round(male_df[male_df.Race == "Asian"].Salary.median(), 2)
male_Korean_median = round(male_df[male_df.Race == "Korean"].Salary.median(), 2)
male_Chinese_median = round(male_df[male_df.Race == "Chinese"].Salary.median(), 2)
male_Australian_median = round(male_df[male_df.Race == "Australian"].Salary.median(), 2)
male_Welsh_median = round(male_df[male_df.Race == "Welsh"].Salary.median(), 2)
male_African_American_median = round(male_df[male_df.Race == "African American"].Salary.median(), 2)
male_Mixed_median = round(male_df[male_df.Race == "Mixed"].Salary.median(), 2)
male_Black_median = round(male_df[male_df.Race == "Black"].Salary.median(), 2)

female_white_median = round(female_df[female_df.Race == "White"].Salary.median(), 2)
female_Hispanic_median = round(female_df[female_df.Race == "Hispanic"].Salary.median(), 2)
female_Asian_median = round(female_df[female_df.Race == "Asian"].Salary.median(), 2)
female_Korean_median = round(female_df[female_df.Race == "Korean"].Salary.median(), 2)
female_Chinese_median = round(female_df[female_df.Race == "Chinese"].Salary.median(), 2)
female_Australian_median = round(female_df[female_df.Race == "Australian"].Salary.median(), 2)
female_Welsh_median = round(female_df[female_df.Race == "Welsh"].Salary.median(), 2)
female_African_American_median = round(female_df[female_df.Race == "African American"].Salary.median(), 2)
female_Mixed_median = round(female_df[female_df.Race == "Mixed"].Salary.median(), 2)
female_Black_median = round(female_df[female_df.Race == "Black"].Salary.median(), 2)

#! Standard Deviation
male_white_std = round(male_df[male_df.Race == "White"].Salary.std(), 2)
male_Hispanic_std = round(male_df[male_df.Race == "Hispanic"].Salary.std(), 2)
male_Asian_std = round(male_df[male_df.Race == "Asian"].Salary.std(), 2)
male_Korean_std = round(male_df[male_df.Race == "Korean"].Salary.std(), 2)
male_Chinese_std = round(male_df[male_df.Race == "Chinese"].Salary.std(), 2)
male_Australian_std = round(male_df[male_df.Race == "Australian"].Salary.std(), 2)
male_Welsh_std = round(male_df[male_df.Race == "Welsh"].Salary.std(), 2)
male_African_American_std = round(male_df[male_df.Race == "African American"].Salary.std(), 2)
male_Mixed_std = round(male_df[male_df.Race == "Mixed"].Salary.std(), 2)
male_Black_std = round(male_df[male_df.Race == "Black"].Salary.std(), 2)

female_white_std = round(female_df[female_df.Race == "White"].Salary.std(), 2)
female_Hispanic_std = round(female_df[female_df.Race == "Hispanic"].Salary.std(), 2)
female_Asian_std = round(female_df[female_df.Race == "Asian"].Salary.std(), 2)
female_Korean_std = round(female_df[female_df.Race == "Korean"].Salary.std(), 2)
female_Chinese_std = round(female_df[female_df.Race == "Chinese"].Salary.std(), 2)
female_Australian_std = round(female_df[female_df.Race == "Australian"].Salary.std(), 2)
female_Welsh_std = round(female_df[female_df.Race == "Welsh"].Salary.std(), 2)
female_African_American_std = round(female_df[female_df.Race == "African American"].Salary.std(), 2)
female_Mixed_std = round(female_df[female_df.Race == "Mixed"].Salary.std(), 2)
female_Black_std = round(female_df[female_df.Race == "Black"].Salary.std(), 2)

#! Max
male_white_max = round(male_df[male_df.Race == "White"].Salary.max(), 2)
male_Hispanic_max= round(male_df[male_df.Race == "Hispanic"].Salary.max(), 2)
male_Asian_max = round(male_df[male_df.Race == "Asian"].Salary.max(), 2)
male_Korean_max= round(male_df[male_df.Race == "Korean"].Salary.max(), 2)
male_Chinese_max = round(male_df[male_df.Race == "Chinese"].Salary.max(), 2)
male_Australian_max = round(male_df[male_df.Race == "Australian"].Salary.max(), 2)
male_Welsh_max = round(male_df[male_df.Race == "Welsh"].Salary.max(), 2)
male_African_American_max = round(male_df[male_df.Race == "African American"].Salary.max(), 2)
male_Mixed_max = round(male_df[male_df.Race == "Mixed"].Salary.max(), 2)
male_Black_max = round(male_df[male_df.Race == "Black"].Salary.max(), 2)

female_white_max = round(female_df[female_df.Race == "White"].Salary.max(), 2)
female_Hispanic_max = round(female_df[female_df.Race == "Hispanic"].Salary.max(), 2)
female_Asian_max = round(female_df[female_df.Race == "Asian"].Salary.max(), 2)
female_Korean_max = round(female_df[female_df.Race == "Korean"].Salary.max(), 2)
female_Chinese_max = round(female_df[female_df.Race == "Chinese"].Salary.max(), 2)
female_Australian_max = round(female_df[female_df.Race == "Australian"].Salary.max(), 2)
female_Welsh_max = round(female_df[female_df.Race == "Welsh"].Salary.max(), 2)
female_African_American_max = round(female_df[female_df.Race == "African American"].Salary.max(), 2)
female_Mixed_max = round(female_df[female_df.Race == "Mixed"].Salary.max(), 2)
female_Black_max = round(female_df[female_df.Race == "Black"].Salary.max(), 2)

#! Min
male_white_min = round(male_df[male_df.Race == "White"].Salary.min(), 2)
male_Hispanic_min= round(male_df[male_df.Race == "Hispanic"].Salary.min(), 2)
male_Asian_min = round(male_df[male_df.Race == "Asian"].Salary.min(), 2)
male_Korean_min= round(male_df[male_df.Race == "Korean"].Salary.min(), 2)
male_Chinese_min = round(male_df[male_df.Race == "Chinese"].Salary.min(), 2)
male_Australian_min = round(male_df[male_df.Race == "Australian"].Salary.min(), 2)
male_Welsh_min = round(male_df[male_df.Race == "Welsh"].Salary.min(), 2)
male_African_American_min = round(male_df[male_df.Race == "African American"].Salary.min(), 2)
male_Mixed_min = round(male_df[male_df.Race == "Mixed"].Salary.min(), 2)
male_Black_min = round(male_df[male_df.Race == "Black"].Salary.min(), 2)

female_white_min = round(female_df[female_df.Race == "White"].Salary.min(), 2)
female_Hispanic_min = round(female_df[female_df.Race == "Hispanic"].Salary.min(), 2)
female_Asian_min = round(female_df[female_df.Race == "Asian"].Salary.min(), 2)
female_Korean_min = round(female_df[female_df.Race == "Korean"].Salary.min(), 2)
female_Chinese_min = round(female_df[female_df.Race == "Chinese"].Salary.min(), 2)
female_Australian_min = round(female_df[female_df.Race == "Australian"].Salary.min(), 2)
female_Welsh_min = round(female_df[female_df.Race == "Welsh"].Salary.min(), 2)
female_African_American_min = round(female_df[female_df.Race == "African American"].Salary.min(), 2)
female_Mixed_min = round(female_df[female_df.Race == "Mixed"].Salary.min(), 2)
female_Black_min = round(female_df[female_df.Race == "Black"].Salary.min(), 2)

#! Range
male_white_diff = male_white_max - male_white_min
male_Hispanic_diff = male_Hispanic_max - male_Hispanic_min
male_Asian_diff = male_Asian_max - male_Asian_min
male_Korean_diff = male_Korean_max - male_Korean_min
male_Chinese_diff = male_Chinese_max - male_Chinese_min
male_Australian_diff = male_Australian_max - male_Australian_min
male_Welsh_diff = male_Welsh_max - male_Welsh_min
male_African_American_diff = male_African_American_max - male_African_American_min
male_Mixed_diff = male_Mixed_max - male_Mixed_min
male_Black_diff = male_Black_max - male_Black_min

female_white_diff = female_white_max - female_white_min
female_Hispanic_diff = female_Hispanic_max - female_Hispanic_min
female_Asian_diff = female_Asian_max - female_Asian_min
female_Korean_diff = female_Korean_max - female_Korean_min
female_Chinese_diff = female_Chinese_max - female_Chinese_min
female_Australian_diff = female_Australian_max - female_Australian_min
female_Welsh_diff = female_Welsh_max - female_Welsh_min
female_African_American_diff = female_African_American_max - female_African_American_min
female_Mixed_diff = female_Mixed_max - female_Mixed_min
female_Black_diff = female_Black_max - female_Black_min

# %%
#* Table data
mean_table = [
    ["White", male_white_mean, female_white_mean],
    ["Hispanic", male_Hispanic_mean, female_Hispanic_mean],
    ["Asian", male_Asian_mean, female_Asian_mean],
    ["Korean", male_Korean_mean, female_Korean_mean],
    ["Chinese", male_Chinese_mean, female_Chinese_mean],
    ["Australian", male_Australian_mean, female_Australian_mean],
    ["Welsh", male_Welsh_mean, female_Welsh_mean],
    ["African American", male_African_American_mean, female_African_American_mean],
    ["Mixed", male_Mixed_mean, female_Mixed_mean],
    ["Black", male_Black_mean, female_Black_mean]
]
median_table = [
    ["White", male_white_median, female_white_median],
    ["Hispanic", male_Hispanic_median, female_Hispanic_median],
    ["Asian", male_Asian_median, female_Asian_median],
    ["Korean", male_Korean_median, female_Korean_median],
    ["Chinese", male_Chinese_median, female_Chinese_median],
    ["Australian", male_Australian_median, female_Australian_median],
    ["Welsh", male_Welsh_median, female_Welsh_median],
    ["African American", male_African_American_median, female_African_American_median],
    ["Mixed", male_Mixed_median, female_Mixed_median],
    ["Black", male_Black_median, female_Black_median]
]
std_table = [
    ["White", male_white_std, female_white_std],
    ["Hispanic", male_Hispanic_std, female_Hispanic_std],
    ["Asian", male_Asian_std, female_Asian_std],
    ["Korean", male_Korean_std, female_Korean_std],
    ["Chinese", male_Chinese_std, female_Chinese_std],
    ["Australian", male_Australian_std, female_Australian_std],
    ["Welsh", male_Welsh_std, female_Welsh_std],
    ["African American", male_African_American_std, female_African_American_std],
    ["Mixed", male_Mixed_std, female_Mixed_std],
    ["Black", male_Black_std, female_Black_std]
]
min_table = [
    ["White", male_white_min, female_white_min],
    ["Hispanic", male_Hispanic_min, female_Hispanic_min],
    ["Asian", male_Asian_min, female_Asian_min],
    ["Koreana", male_Korean_min, female_Korean_min],
    ["Chinese", male_Chinese_min, female_Chinese_min],
    ["Australian", male_Australian_min, female_Australian_min],
    ["Welsh", male_Welsh_min, female_Welsh_min],
    ["African American", male_African_American_min, female_African_American_min],
    ["Mixed", male_Mixed_min, female_Mixed_min],
    ["Black", male_Black_min, female_Black_min]
]
max_table = [
    ["White", male_white_max, female_white_max],
    ["Hispanic", male_Hispanic_max, female_Hispanic_max],
    ["Asian", male_Asian_max, female_Asian_max],
    ["Korean", male_Korean_max, female_Korean_max],
    ["Chinese", male_Chinese_max, female_Chinese_max],
    ["Australian", male_Australian_max, female_Australian_max],
    ["Welsh", male_Welsh_max, female_Welsh_max],
    ["African American", male_African_American_max, female_African_American_max],
    ["Mixed", male_Mixed_max, female_Mixed_max],
    ["Black", male_Black_max, female_Black_max]
]
diff_table = [
    ["White", male_white_diff, female_white_diff],
    ["Hispanic", male_Hispanic_diff, female_Hispanic_diff],
    ["Asian", male_Asian_diff, female_Asian_diff],
    ["Korean", male_Korean_diff, female_Korean_diff],
    ["Chinese", male_Chinese_diff, female_Chinese_diff],
    ["Australian", male_Australian_diff, female_Australian_diff],
    ["Welsh", male_Welsh_diff, female_Welsh_diff],
    ["African American", male_African_American_diff, female_African_American_diff],
    ["Mixed", male_Mixed_diff, female_Mixed_diff],
    ["Black", male_Black_diff, female_Black_diff]
]

# Modified table creator function to account for Nan values
def table_creator(table_data):
    formatted_table_data = []

    for row in table_data:
        formatted_row = []
        headers_list = ["Race", "Male", "Female"]

        for value in row:
            if isinstance(value, (int, float)) and not math.isnan(value):
                formatted_value = f"{round(value):,.0f}"
            elif isinstance(value, str):
                formatted_value = value
            else:
                formatted_value = str(value)
            formatted_row.append(formatted_value)
        formatted_table_data.append(formatted_row)

    table = tabulate(formatted_table_data, headers_list, tablefmt="fancy_grid")
    return table

print("Mean Salary Table")
formatted_table = table_creator(mean_table)
print(formatted_table, '\n')

print("Median Salary Table")
formatted_table = table_creator(median_table)
print(formatted_table, '\n')

print("Standard Deviation Table")
formatted_table = table_creator(std_table)
print(formatted_table, '\n')

print("Maximum Salary Table")
formatted_table = table_creator(max_table)
print(formatted_table, '\n')

print("Minimum Salary Table")
formatted_table = table_creator(min_table)
print(formatted_table, '\n')

print("Salary Range Table")
formatted_table = table_creator(diff_table)
print(formatted_table, '\n')
# Out:
# Mean Salary Table
# ╒══════════════════╤═════════╤══════════╕
# │ Race             │ Male    │ Female   │
# ╞══════════════════╪═════════╪══════════╡
# │ White            │ 123,191 │ 109,595  │
# ├──────────────────┼─────────┼──────────┤
# │ Hispanic         │ 114,892 │ 104,509  │
# ├──────────────────┼─────────┼──────────┤
# │ Asian            │ 122,435 │ 106,381  │
# ├──────────────────┼─────────┼──────────┤
# │ Korean           │ 122,565 │ 110,948  │
# ├──────────────────┼─────────┼──────────┤
# │ Chinese          │ 115,078 │ 106,423  │
# ├──────────────────┼─────────┼──────────┤
# │ Australian       │ 119,390 │ 108,245  │
# ├──────────────────┼─────────┼──────────┤
# │ Welsh            │ 116,667 │ 108,380  │
# ├──────────────────┼─────────┼──────────┤
# │ African American │ 118,957 │ 103,568  │
# ├──────────────────┼─────────┼──────────┤
# │ Mixed            │ 122,652 │ 108,091  │
# ├──────────────────┼─────────┼──────────┤
# │ Black            │ 126,169 │ 108,602  │
# ...

# %% [markdown]
# ## Findings across different Races:
# - The largest salary difference occurs across Blacks a when looking at mean/ median.
# - The smallest salary difference occurs across Welsh when looking at mean/ median.
