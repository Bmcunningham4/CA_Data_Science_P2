# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

salary_df = pd.read_csv("Salary.csv") #? remember I don't need to do a new one!

# %%
#? I think go through all histograms and then all boxplots, all contigency etc.. pump them out while I'm flowing with each!!
#* Side by side boxplots
""" 
sns.boxplot(data = df, x = 'column1', y = 'column2')
plt.show()
#todo: Common theme for every bit of plotting always close after show with : (fixes everything)
plt.close() 
"""
def age_group_funct(age):
    if 19 < age < 30:
        return "20 - 29"
    elif 29 < age < 40:
        return "30 - 39"
    elif 39 < age < 50:
        return "40 - 49"
    else: 
        return "50+"

salary_df["Age Group"] = salary_df.Age.apply(age_group_funct)
age_order = ["20 - 29", "30 - 39", "40 - 49", "50+"]

sns.boxplot(data = salary_df, x = "Age Group", y = "Salary", order = age_order, hue="Gender")
plt.show()
plt.close()
